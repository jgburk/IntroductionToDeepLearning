# %% [markdown]
# # R Examples
# upload rse_gene.Rdata

# %%
z <- "a"

# %%
getwd()
# Out:
# [1] "/content"

# %%
z <- c(1,2,3)

print(z[1])
# Out:
# [1] 1

# %%
library(magrittr)

z %>% print(.)
# Out:
# [1] 1 2 3

# %%
installed.packages()
# Out:
#                  Package          LibPath                       Version
# abind            abind            /usr/local/lib/R/site-library 1.4-5
# assertthat       assertthat       /usr/local/lib/R/site-library 0.2.1
# Biobase          Biobase          /usr/local/lib/R/site-library 2.62.0
# BiocGenerics     BiocGenerics     /usr/local/lib/R/site-library 0.48.1
# BiocManager      BiocManager      /usr/local/lib/R/site-library 1.30.22
# BiocVersion      BiocVersion      /usr/local/lib/R/site-library 3.18.0
# bitops           bitops           /usr/local/lib/R/site-library 1.0-7
# DelayedArray     DelayedArray     /usr/local/lib/R/site-library 0.28.0
# GenomeInfoDb     GenomeInfoDb     /usr/local/lib/R/site-library 1.38.1
# GenomeInfoDbData GenomeInfoDbData /usr/local/lib/R/site-library 1.2.11
# GenomicRanges    GenomicRanges    /usr/local/lib/R/site-library 1.54.1
# geometry         geometry         /usr/local/lib/R/site-library 0.4.7
# IRanges          IRanges          /usr/local/lib/R/site-library 2.36.0
# IRdisplay        IRdisplay        /usr/local/lib/R/site-library 1.1
# IRkernel         IRkernel         /usr/local/lib/R/site-library 1.3.2
# linprog          linprog          /usr/local/lib/R/site-library 0.9-4
# lpSolve          lpSolve          /usr/local/lib/R/site-library 5.6.19
# magic            magic            /usr/local/lib/R/site-library 1.6-1
# MatrixGenerics   MatrixGenerics   /usr/local/lib/R/site-library 1.14.0
# matrixStats      matrixStats      /usr/local/lib/R/site-library 1.1.0
# pbdZMQ           pbdZMQ           /usr/local/lib/R/site-library 0.3-10
# pdfCluster       pdfCluster       /usr/local/lib/R/site-library 1.0-4
# plyr             plyr             /usr/local/lib/R/site-library 1.8.9
# pROC             pROC             /usr/local/lib/R/site-library 1.18.5
# Rcpp             Rcpp             /usr/local/lib/R/site-library 1.0.11
# RcppProgress     RcppProgress     /usr/local/lib/R/site-library 0.4.2
# RCurl            RCurl            /usr/local/lib/R/site-library 1.98-1.13
# repr             repr             /usr/local/lib/R/site-library 1.1.6
# S4Arrays         S4Arrays         /usr/local/lib/R/site-library 1.2.0
# S4Vectors        S4Vectors        /usr/local/lib/R/site-library 0.40.1
# ⋮                ⋮                ⋮                             ⋮
# zip              zip              /usr/lib/R/site-library       2.3.0
# base             base             /usr/lib/R/library            4.3.2
# boot             boot             /usr/lib/R/library            1.3-28
# class            class            /usr/lib/R/library            7.3-22
# cluster          cluster          /usr/lib/R/library            2.1.4
# codetools        codetools        /usr/lib/R/library            0.2-19
# compiler         compiler         /usr/lib/R/library            4.3.2
# datasets         datasets         /usr/lib/R/library            4.3.2
# foreign          foreign          /usr/lib/R/library            0.8-85
# graphics         graphics         /usr/lib/R/library            4.3.2
# grDevices        grDevices        /usr/lib/R/library            4.3.2
# grid             grid             /usr/lib/R/library            4.3.2
# KernSmooth       KernSmooth       /usr/lib/R/library            2.23-22
# lattice          lattice          /usr/lib/R/library            0.22-5
# MASS             MASS             /usr/lib/R/library            7.3-60
# Matrix           Matrix           /usr/lib/R/library            1.6-1.1
# methods          methods          /usr/lib/R/library            4.3.2
# mgcv             mgcv             /usr/lib/R/library            1.9-0
# nlme             nlme             /usr/lib/R/library            3.1-163
# nnet             nnet             /usr/lib/R/library            7.3-19
# parallel         parallel         /usr/lib/R/library            4.3.2
# rpart            rpart            /usr/lib/R/library            4.1.21
# spatial          spatial          /usr/lib/R/library            7.3-17
# splines          splines          /usr/lib/R/library            4.3.2
# stats            stats            /usr/lib/R/library            4.3.2
# stats4           stats4           /usr/lib/R/library            4.3.2
# survival         survival         /usr/lib/R/library            3.5-7
# tcltk            tcltk            /usr/lib/R/library            4.3.2
# tools            tools            /usr/lib/R/library            4.3.2
# utils            utils            /usr/lib/R/library            4.3.2
#                  Priority
# abind            NA
# assertthat       NA
# Biobase          NA
# BiocGenerics     NA
# BiocManager      NA
# BiocVersion      NA
# bitops           NA
# DelayedArray     NA
# GenomeInfoDb     NA
# GenomeInfoDbData NA
# GenomicRanges    NA
# geometry         NA
# IRanges          NA
# IRdisplay        NA
# IRkernel         NA
# linprog          NA
# lpSolve          NA
# magic            NA
# MatrixGenerics   NA
# matrixStats      NA
# pbdZMQ           NA
# pdfCluster       NA
# plyr             NA
# pROC             NA
# Rcpp             NA
# RcppProgress     NA
# RCurl            NA
# repr             NA
# S4Arrays         NA
# S4Vectors        NA
# ⋮                ⋮
# zip              NA
# base             base
# boot             recommended
# class            recommended
# cluster          recommended
# codetools        recommended
# compiler         base
# datasets         base
# foreign          recommended
# graphics         base
# grDevices        base
# grid             base
# KernSmooth       recommended
# lattice          recommended
# MASS             recommended
# Matrix           recommended
# methods          base
# mgcv             recommended
# nlme             recommended
# nnet             recommended
# parallel         base
# rpart            recommended
# spatial          recommended
# splines          base
# stats            base
# stats4           base
# survival         recommended
# tcltk            base
# tools            base
# utils            base
#                  Depends
# abind            R (>= 1.5.0)
# assertthat       NA
# Biobase          R (>= 2.10), BiocGenerics (>= 0.27.1), utils
# BiocGenerics     R (>= 4.0.0), methods, utils, graphics, stats
# BiocManager      NA
# BiocVersion      R (>= 4.3.0)
# bitops           NA
# DelayedArray     R (>= 4.0.0), methods, stats4, Matrix, BiocGenerics (>=\n0.43.4), MatrixGenerics (>= 1.1.3), S4Vectors (>= 0.27.2),\nIRanges (>= 2.17.3), S4Arrays (>= 1.1.1), SparseArray (>=\n1.1.10)
# GenomeInfoDb     R (>= 4.0.0), methods, BiocGenerics (>= 0.37.0), S4Vectors (>=\n0.25.12), IRanges (>= 2.13.12)
# GenomeInfoDbData R (>= 3.5.0)
# GenomicRanges    R (>= 4.0.0), methods, stats4, BiocGenerics (>= 0.37.0),\nS4Vectors (>= 0.27.12), IRanges (>= 2.31.2), GenomeInfoDb (>=\n1.15.2)
# geometry         R (>= 3.0.0)
# IRanges          R (>= 4.0.0), methods, utils, stats, BiocGenerics (>= 0.39.2),\nS4Vectors (>= 0.33.3)
# IRdisplay        R (>= 3.0.1)
# IRkernel         R (>= 3.2.0)
# linprog          R (>= 2.4.0), lpSolve
# lpSolve          NA
# magic            R (>= 2.10), abind
# MatrixGenerics   matrixStats (>= 1.0.0)
# matrixStats      R (>= 2.12.0)
# pbdZMQ           R (>= 3.5.0)
# pdfCluster       NA
# plyr             R (>= 3.1.0)
# pROC             R (>= 2.14)
# Rcpp             NA
# RcppProgress     NA
# RCurl            R (>= 3.4.0), methods
# repr             R (>= 3.0.1)
# S4Arrays         R (>= 4.3.0), methods, Matrix, abind, BiocGenerics (>=\n0.45.2), S4Vectors, IRanges
# S4Vectors        R (>= 4.0.0), methods, utils, stats, stats4, BiocGenerics (>=\n0.37.0)
# ⋮                ⋮
# zip              NA
# base             NA
# boot             R (>= 3.0.0), graphics, stats
# class            R (>= 3.0.0), stats, utils
# cluster          R (>= 3.5.0)
# codetools        R (>= 2.1)
# compiler         NA
# datasets         NA
# foreign          R (>= 4.0.0)
# graphics         NA
# grDevices        NA
# grid             NA
# KernSmooth       R (>= 2.5.0), stats
# lattice          R (>= 4.0.0)
# MASS             R (>= 4.0), grDevices, graphics, stats, utils
# Matrix           R (>= 3.5.0), methods
# methods          NA
# mgcv             R (>= 3.6.0), nlme (>= 3.1-64)
# nlme             R (>= 3.5.0)
# nnet             R (>= 3.0.0), stats, utils
# parallel         NA
# rpart            R (>= 2.15.0), graphics, stats, grDevices
# spatial          R (>= 3.0.0), graphics, stats, utils
# splines          NA
# stats            NA
# stats4           NA
# survival         R (>= 3.5.0)
# tcltk            NA
# tools            NA
# utils            NA
#                  Imports
# abind            methods, utils
# assertthat       tools
# Biobase          methods
# BiocGenerics     methods, utils, graphics, stats
# BiocManager      utils
# BiocVersion      NA
# bitops           NA
# DelayedArray     stats
# GenomeInfoDb     stats, stats4, utils, RCurl, GenomeInfoDbData
# GenomeInfoDbData NA
# GenomicRanges    utils, stats, XVector (>= 0.29.2)
# geometry         magic, Rcpp, lpSolve, linprog
# IRanges          stats4
# IRdisplay        methods, repr
# IRkernel         repr (>= 0.4.99), methods, evaluate (>= 0.10), IRdisplay (>=\n0.3.0.9999), pbdZMQ (>= 0.2-1), crayon, jsonlite (>= 0.9.6),\nuuid, digest
# linprog          NA
# lpSolve          NA
# magic            NA
# MatrixGenerics   methods
# matrixStats      NA
# pbdZMQ           NA
# pdfCluster       geometry, methods
# plyr             Rcpp (>= 0.11.0)
# pROC             methods, plyr, Rcpp (>= 0.11.1)
# Rcpp             methods, utils
# RcppProgress     NA
# RCurl            bitops
# repr             utils, grDevices, htmltools, jsonlite, pillar (>= 1.4.0),\nbase64enc
# S4Arrays         stats, crayon
# S4Vectors        NA
# ⋮                ⋮
# zip              NA
# base             NA
# boot             NA
# class            MASS
# cluster          graphics, grDevices, stats, utils
# codetools        NA
# compiler         NA
# datasets         NA
# foreign          methods, utils, stats
# graphics         grDevices
# grDevices        NA
# grid             grDevices, utils
# KernSmooth       NA
# lattice          grid, grDevices, graphics, stats, utils
# MASS             methods
# Matrix           grDevices, graphics, grid, lattice, stats, utils
# methods          utils, stats
# mgcv             methods, stats, graphics, Matrix, splines, utils
# nlme             graphics, stats, utils, lattice
# nnet             NA
# parallel         tools, compiler
# rpart            NA
# spatial          NA
# splines          graphics, stats
# stats            utils, grDevices, graphics
# stats4           graphics, methods, stats
# survival         graphics, Matrix, methods, splines, stats, utils
# tcltk            utils
# tools            NA
# utils            NA
#                  LinkingTo
# abind            NA
# assertthat       NA
# Biobase          NA
# BiocGenerics     NA
# BiocManager      NA
# BiocVersion      NA
# bitops           NA
# DelayedArray     S4Vectors
# GenomeInfoDb     NA
# GenomeInfoDbData NA
# GenomicRanges    S4Vectors, IRanges
# geometry         Rcpp, RcppProgress
# IRanges          S4Vectors
# IRdisplay        NA
# IRkernel         NA
# linprog          NA
# lpSolve          NA
# magic            NA
# MatrixGenerics   NA
# matrixStats      NA
# pbdZMQ           NA
# pdfCluster       NA
# plyr             Rcpp
# pROC             Rcpp
# Rcpp             NA
# RcppProgress     NA
# RCurl            NA
# repr             NA
# S4Arrays         S4Vectors
# S4Vectors        NA
# ⋮                ⋮
# zip              NA
# base             NA
# boot             NA
# class            NA
# cluster          NA
# codetools        NA
# compiler         NA
# datasets         NA
# foreign          NA
# graphics         NA
# grDevices        NA
# grid             NA
# KernSmooth       NA
# lattice          NA
# MASS             NA
# Matrix           NA
# methods          NA
# mgcv             NA
# nlme             NA
# nnet             NA
# parallel         NA
# rpart            NA
# spatial          NA
# splines          NA
# stats            NA
# stats4           NA
# survival         NA
# tcltk            NA
# tools            NA
# utils            NA
#                  Suggests
# abind            NA
# assertthat       testthat, covr
# Biobase          tools, tkWidgets, ALL, RUnit, golubEsets, BiocStyle, knitr
# BiocGenerics     Biobase, S4Vectors, IRanges, GenomicRanges, DelayedArray,\nBiostrings, Rsamtools, AnnotationDbi, affy, affyPLM, DESeq2,\nflowClust, MSnbase, annotate, RUnit
# BiocManager      BiocVersion, remotes, rmarkdown, testthat, withr, curl, knitr
# BiocVersion      NA
# bitops           NA
# DelayedArray     BiocParallel, HDF5Array (>= 1.17.12), genefilter,\nSummarizedExperiment, airway, lobstr, DelayedMatrixStats,\nknitr, rmarkdown, BiocStyle, RUnit
# GenomeInfoDb     GenomicRanges, Rsamtools, GenomicAlignments, GenomicFeatures,\nTxDb.Dmelanogaster.UCSC.dm3.ensGene, BSgenome,\nBSgenome.Scerevisiae.UCSC.sacCer2, BSgenome.Celegans.UCSC.ce2,\nBSgenome.Hsapiens.NCBI.GRCh38, RUnit, BiocStyle, knitr
# GenomeInfoDbData NA
# GenomicRanges    Matrix, Biobase, AnnotationDbi, annotate, Biostrings (>=\n2.25.3), SummarizedExperiment (>= 0.1.5), Rsamtools (>=\n1.13.53), GenomicAlignments, rtracklayer, BSgenome,\nGenomicFeatures, Gviz, VariantAnnotation, AnnotationHub,\nDESeq2, DEXSeq, edgeR, KEGGgraph, RNAseqData.HNRNPC.bam.chr14,\npasillaBamSubset, KEGGREST, hgu95av2.db, hgu95av2probe,\nBSgenome.Scerevisiae.UCSC.sacCer2, BSgenome.Hsapiens.UCSC.hg19,\nBSgenome.Mmusculus.UCSC.mm10,\nTxDb.Athaliana.BioMart.plantsmart22,\nTxDb.Dmelanogaster.UCSC.dm3.ensGene,\nTxDb.Hsapiens.UCSC.hg19.knownGene,\nTxDb.Mmusculus.UCSC.mm10.knownGene, RUnit, digest, knitr,\nrmarkdown, BiocStyle
# geometry         spelling, testthat, rgl, R.matlab, interp
# IRanges          XVector, GenomicRanges, Rsamtools, GenomicAlignments,\nGenomicFeatures, BSgenome.Celegans.UCSC.ce2, pasillaBamSubset,\nRUnit, BiocStyle
# IRdisplay        testthat, withr
# IRkernel         testthat, roxygen2
# linprog          NA
# lpSolve          NA
# magic            NA
# MatrixGenerics   Matrix, sparseMatrixStats, SparseArray, DelayedArray,\nDelayedMatrixStats, SummarizedExperiment, testthat (>= 2.1.0)
# matrixStats      base64enc, ggplot2, knitr, markdown, microbenchmark,\nR.devices, R.rsp
# pbdZMQ           NA
# pdfCluster       cluster
# plyr             abind, covr, doParallel, foreach, iterators, itertools,\ntcltk, testthat
# pROC             microbenchmark, tcltk, MASS, logcondens, doParallel,\ntestthat, vdiffr, ggplot2, rlang
# Rcpp             tinytest, inline, rbenchmark, pkgKitten (>= 0.1.2)
# ...
# survival         NA
# tcltk            NA
# tools            codetools, methods, xml2, curl, commonmark, knitr, xfun,\nmathjaxr, V8
# utils            methods, xml2, commonmark, knitr
#                  Enhances
# abind            NA
# assertthat       NA
# Biobase          NA
# BiocGenerics     NA
# BiocManager      NA
# BiocVersion      NA
# bitops           NA
# DelayedArray     NA
# GenomeInfoDb     NA
# GenomeInfoDbData NA
# GenomicRanges    NA
# geometry         NA
# IRanges          NA
# IRdisplay        NA
# IRkernel         NA
# linprog          NA
# lpSolve          NA
# magic            NA
# MatrixGenerics   NA
# matrixStats      NA
# pbdZMQ           NA
# pdfCluster       NA
# plyr             NA
# pROC             NA
# Rcpp             NA
# RcppProgress     NA
# RCurl            NA
# repr             data.table, tibble, htmlwidgets, vegalite, plotly, geojsonio
# S4Arrays         NA
# S4Vectors        NA
# ⋮                ⋮
# zip              NA
# base             NA
# boot             NA
# class            NA
# cluster          NA
# codetools        NA
# compiler         NA
# datasets         NA
# foreign          NA
# graphics         NA
# grDevices        NA
# grid             NA
# KernSmooth       NA
# lattice          chron, zoo
# MASS             NA
# Matrix           SparseM, graph
# methods          NA
# mgcv             NA
# nlme             NA
# nnet             NA
# parallel         snow, Rmpi
# rpart            NA
# spatial          NA
# splines          NA
# stats            NA
# stats4           NA
# survival         NA
# tcltk            NA
# tools            NA
# utils            NA
#                  License                     License_is_FOSS
# abind            LGPL (>= 2)                 NA
# assertthat       GPL-3                       NA
# Biobase          Artistic-2.0                NA
# BiocGenerics     Artistic-2.0                NA
# BiocManager      Artistic-2.0                NA
# BiocVersion      Artistic-2.0                NA
# bitops           GPL (>= 2)                  NA
# DelayedArray     Artistic-2.0                NA
# GenomeInfoDb     Artistic-2.0                NA
# GenomeInfoDbData Artistic-2.0                NA
# GenomicRanges    Artistic-2.0                NA
# geometry         GPL (>= 3)                  NA
# IRanges          Artistic-2.0                NA
# IRdisplay        MIT + file LICENSE          NA
# IRkernel         MIT + file LICENSE          NA
# linprog          GPL (>= 2)                  NA
# lpSolve          LGPL-2                      NA
# magic            GPL-2                       NA
# MatrixGenerics   Artistic-2.0                NA
# matrixStats      Artistic-2.0                NA
# pbdZMQ           GPL-3                       NA
# pdfCluster       GPL-2                       NA
# plyr             MIT + file LICENSE          NA
# pROC             GPL (>= 3)                  NA
# Rcpp             GPL (>= 2)                  NA
# RcppProgress     GPL (>= 3)                  NA
# RCurl            BSD_3_clause + file LICENSE NA
# repr             GPL (>= 3)                  NA
# S4Arrays         Artistic-2.0                NA
# S4Vectors        Artistic-2.0                NA
# ⋮                ⋮                           ⋮
# zip              MIT + file LICENSE          NA
# base             Part of R 4.3.2             NA
# boot             Unlimited                   NA
# class            GPL-2 | GPL-3               NA
# cluster          GPL (>= 2)                  NA
# codetools        GPL                         NA
# compiler         Part of R 4.3.2             NA
# datasets         Part of R 4.3.2             NA
# foreign          GPL (>= 2)                  NA
# graphics         Part of R 4.3.2             NA
# grDevices        Part of R 4.3.2             NA
# grid             Part of R 4.3.2             NA
# KernSmooth       Unlimited                   NA
# lattice          GPL (>= 2)                  NA
# MASS             GPL-2 | GPL-3               NA
# Matrix           GPL (>= 2) | file LICENCE   NA
# methods          Part of R 4.3.2             NA
# mgcv             GPL (>= 2)                  NA
# nlme             GPL (>= 2)                  NA
# nnet             GPL-2 | GPL-3               NA
# parallel         Part of R 4.3.2             NA
# rpart            GPL-2 | GPL-3               NA
# spatial          GPL-2 | GPL-3               NA
# splines          Part of R 4.3.2             NA
# stats            Part of R 4.3.2             NA
# stats4           Part of R 4.3.2             NA
# survival         LGPL (>= 2)                 NA
# tcltk            Part of R 4.3.2             NA
# tools            Part of R 4.3.2             NA
# utils            Part of R 4.3.2             NA
#                  License_restricts_use OS_type MD5sum NeedsCompilation Built
# abind            NA                    NA      NA     no               4.3.2
# assertthat       NA                    NA      NA     no               4.3.2
# Biobase          NA                    NA      NA     yes              4.3.2
# BiocGenerics     NA                    NA      NA     no               4.3.2
# BiocManager      NA                    NA      NA     no               4.3.2
# BiocVersion      NA                    NA      NA     no               4.3.2
# bitops           NA                    NA      NA     yes              4.3.2
# DelayedArray     NA                    NA      NA     yes              4.3.2
# GenomeInfoDb     NA                    NA      NA     no               4.3.2
# GenomeInfoDbData NA                    NA      NA     no               4.3.2
# GenomicRanges    NA                    NA      NA     yes              4.3.2
# geometry         NA                    NA      NA     yes              4.3.2
# IRanges          NA                    NA      NA     yes              4.3.2
# IRdisplay        NA                    NA      NA     no               4.3.2
# IRkernel         NA                    NA      NA     no               4.3.2
# linprog          NA                    NA      NA     no               4.3.2
# lpSolve          NA                    NA      NA     yes              4.3.2
# magic            NA                    NA      NA     no               4.3.2
# MatrixGenerics   NA                    NA      NA     no               4.3.2
# matrixStats      NA                    NA      NA     yes              4.3.2
# pbdZMQ           NA                    NA      NA     yes              4.3.2
# pdfCluster       NA                    NA      NA     yes              4.3.2
# plyr             NA                    NA      NA     yes              4.3.2
# pROC             NA                    NA      NA     yes              4.3.2
# Rcpp             NA                    NA      NA     yes              4.3.2
# RcppProgress     NA                    NA      NA     no               4.3.2
# RCurl            NA                    NA      NA     yes              4.3.2
# repr             NA                    NA      NA     no               4.3.2
# S4Arrays         NA                    NA      NA     yes              4.3.2
# S4Vectors        NA                    NA      NA     yes              4.3.2
# ⋮                ⋮                     ⋮       ⋮      ⋮                ⋮
# zip              NA                    NA      NA     yes              4.3.0
# base             NA                    NA      NA     NA               4.3.2
# boot             NA                    NA      NA     no               4.2.0
# class            NA                    NA      NA     yes              4.3.1
# cluster          NA                    NA      NA     yes              4.2.1
# codetools        NA                    NA      NA     no               4.2.2
# compiler         NA                    NA      NA     NA               4.3.2
# datasets         NA                    NA      NA     NA               4.3.2
# foreign          NA                    NA      NA     yes              4.3.1
# graphics         NA                    NA      NA     yes              4.3.2
# grDevices        NA                    NA      NA     yes              4.3.2
# grid             NA                    NA      NA     yes              4.3.2
# KernSmooth       NA                    NA      NA     yes              4.3.1
# lattice          NA                    NA      NA     yes              4.3.1
# MASS             NA                    NA      NA     yes              4.3.1
# Matrix           NA                    NA      NA     yes              4.3.1
# methods          NA                    NA      NA     yes              4.3.2
# mgcv             NA                    NA      NA     yes              4.3.1
# nlme             NA                    NA      NA     yes              4.3.1
# nnet             NA                    NA      NA     yes              4.3.1
# parallel         NA                    NA      NA     yes              4.3.2
# rpart            NA                    NA      NA     yes              4.3.1
# spatial          NA                    NA      NA     yes              4.3.1
# splines          NA                    NA      NA     yes              4.3.2
# stats            NA                    NA      NA     yes              4.3.2
# stats4           NA                    NA      NA     NA               4.3.2
# survival         NA                    NA      NA     yes              4.3.1
# tcltk            NA                    NA      NA     yes              4.3.2
# tools            NA                    NA      NA     yes              4.3.2
# utils            NA                    NA      NA     yes              4.3.2

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("SummarizedExperiment")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'SummarizedExperiment'”
# Old packages: 'bit', 'curl', 'devtools', 'gargle', 'highr', 'isoband',
#   'lifecycle', 'openssl', 'ragg', 'roxygen2', 'stringi', 'textshaping',
#   'whisker', 'boot', 'Matrix'

# %%
set.seed(88888888)

library(scales)

ETA <<- 0.01

# input layer
NUM_FEATURES <<- 2
INPUT_WIDTH <<- NUM_FEATURES + 1 # (bias)

# hidden layer
HIDDEN_LAYER_WIDTH <<- 5
ANN_WIDTH <<- HIDDEN_LAYER_WIDTH + 1 # (bias)

# output layer
NUM_CLASSES <<- 3
OUTPUT_WIDTH <<- NUM_CLASSES

NUM_EPOCHS <- 3000

# ----------------               -                -----------
# num features + 1 (input axons) 6 (hidden_axons) num classes
# ----------------               -                -----------

# input layer
input_activation <<- matrix(data = 1,
                            nrow = INPUT_WIDTH,
                            ncol = 1)
input_axon_w <<- matrix(data = runif(n = HIDDEN_LAYER_WIDTH * INPUT_WIDTH),
                        nrow = INPUT_WIDTH,
                        ncol = HIDDEN_LAYER_WIDTH)
# hidden layer
hidden_deltas <<- matrix(data = 1,
                         nrow = HIDDEN_LAYER_WIDTH,
                         ncol = 1)
hidden_activation <<- matrix(data = 1,
                             nrow = ANN_WIDTH,
                             ncol = 1)
hidden_axon_w <<- matrix(data = runif(n = ANN_WIDTH * OUTPUT_WIDTH),
                         nrow = ANN_WIDTH,
                         ncol = OUTPUT_WIDTH)
# output layer
output_deltas <<- matrix(data = 1,
                         nrow = OUTPUT_WIDTH,
                         ncol = 1)
output_activation <<- matrix(data = 1,
                             nrow = OUTPUT_WIDTH,
                             ncol = 1)

activation_function <- function(x){
  1/(1 + exp(-(x)))
}

activation_function_derivative <- function(x){
  activation_function(x)*(1 - activation_function(x))
}

forward_prop <- function(training_sample_features){
  # input layer
  input_activation <<- c(training_sample_features,1)

  hidden_activation <<-
    c(activation_function(t(input_axon_w) %*% input_activation),1)

  output_activation <<-
    activation_function(t(hidden_axon_w) %*% hidden_activation)
}

encode_class <- function(sample_class){
  ann_class_encoding <- numeric(NUM_CLASSES)
  ann_class_encoding[sample_class] <- 1
  return(ann_class_encoding)
}

calc_err <- function(sample_class){
  ann_class_encoding <- encode_class(sample_class)
  return(output_activation - ann_class_encoding)
}

backward_prop <- function(sample_class){
  output_deltas <<- calc_err(sample_class)

  hidden_deltas <<-
    hidden_axon_w %*%
    output_deltas *
    activation_function_derivative(hidden_activation)

  input_axon_w <<-
    input_axon_w -
    ETA *
    input_activation %*%
    t(hidden_deltas[1:HIDDEN_LAYER_WIDTH])

  hidden_axon_w <<-
    hidden_axon_w -
    ETA *
    hidden_activation %*%
    t(output_deltas)

  return(mean(abs(output_activation - encode_class(sample_class))))
}

train <- function(training_samples_features, training_samples_classes){
  error_mean <- c()
  for(x in 1:NUM_EPOCHS){
    error_sum <- 0
    for(i in 1:nrow(training_samples_features)){
      forward_prop(training_samples_features[i,])
      error_sum <- error_sum + backward_prop(training_samples_classes[i])
    }
    error_mean <- c(error_mean,error_sum/nrow(training_samples_features))
  }
  plot(error_mean,
       xlab="Epoch",
       ylab="Error",
       main="Mean Training Error each Epoch")
}

predict0 <- function(test_sample_features){
  forward_prop(test_sample_features)
  prediction <- output_activation
  #print(output_activation)
  return(which(prediction == max(prediction)))
}

predict_n <- function(test_samples_features){
  ps <- c()
  for(i in 1:nrow(test_samples_features)){
    ps <- c(ps,predict0(test_samples_features[i,]))
  }
  return(ps)
}

samples_f <- matrix(
  c(0,0,
    0,.2,
    .3,.3,
    .3,.3,
    .3,.1,
    .6,.15,
    .6,.2,
    .6,.3,
    .6,.1,
    .6,.35,
    .8,.8,
    .8,.25,
    .8,.1,
    .8,.3,
    .8,.2,
    .8,.4),
  nrow = 16,
  ncol = 2,
  byrow = TRUE)

samples_c <- matrix(
  c(2,2,2,2,1,1,1,1,1,1,3,3,3,3,3,3),
  nrow = 16,
  ncol = 1,
  byrow = TRUE
)

norm_samples_f <- scales::rescale(samples_f, to = c(0,1))
train(norm_samples_f, samples_c)

plot(norm_samples_f,col=samples_c,pch=samples_c * 2,
     xlab="Column 1 Data",
     ylab="Column 2 Data",
     main="True Labels")

pred_train <- predict_n(norm_samples_f)
n_wrong <- sum(pred_train != samples_c)
n_total <- length(samples_c)
accuracy <- (1 - (n_wrong / n_total)) * 100
plot(norm_samples_f,col=pred_train,pch=pred_train * 2,
     xlab="Column 1 Data",
     ylab="Column 2 Data",
     main=paste("Predicted Labels: ",
                n_total - n_wrong," of ",n_total,
                " (",accuracy,"%) correct",sep=""))
if(n_wrong == 1){
  points(x=norm_samples_f[which(pred_train != samples_c),][1],
       y=norm_samples_f[which(pred_train != samples_c),][2],
       pch=1,
       cex=5)
}

rand_points <<- matrix(data = runif(n = 2 * 100),
                       nrow = 100,
                       ncol = 2)
norm_rand_points <- scales::rescale(rand_points, to = c(0,1))
pred_classes <- predict_n(norm_rand_points)
plot(norm_rand_points,col=pred_classes,pch=pred_classes * 2,
     xlab="Column 1 Dimension",
     ylab="Column 2 Dimension",
     main="Decision Boundary")
# Out:
# Plot with title “Mean Training Error each Epoch”
# Plot with title “True Labels”
# Plot with title “Predicted Labels: 15 of 16 (93.75%) correct”
# Plot with title “Decision Boundary”

# %%
install.packages("pROC")
install.packages("assertthat")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("pdfCluster")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
FEATURE_COUNT <- 16 # 1000

# %%
set.seed(88888888)

library(magrittr)
library(assertthat)
library(SummarizedExperiment)

NUM_FEATURES <- FEATURE_COUNT
DATA_DIR <- "./" #"/home/jgburk/PycharmProjects/IntroductionToDeepLearning/"
INPUT_DATA_FN <- "rse_gene.Rdata"
OUTPUT_DATA_FN <- "transposed.Rds"

# from https://trace.ncbi.nlm.nih.gov/Traces/sra/?study=SRP057500
# "RNA-seq of tumor-educated platelets enables blood-based pan-cancer, multiclass and molecular pathway cancer diagnostics"
# six different malignant tumors and blood platelets isolated from healthy individuals
# (1) breast cancer
# (2) colorectal cancer
# (3) glioblastoma *brain*
# (4) healthy controls
# (5) hepatobiliary carcinoma *liver*
# (6) non-small cell lung cancer
# (7) pancreatic cancer

load(paste(DATA_DIR,INPUT_DATA_FN,sep=""))
g <- character()
for(i in 1:length(rse_gene$characteristics)){
  g <- c(g,strsplit(rse_gene$characteristics %>% .[i] %>% unlist() %>% sort() %>% .[2],": ")[[1]][2])
}
stopifnot(assertthat::are_equal(length(g),288))
g_mapping <- g %>% table()
print(g_mapping)
print(names(g_mapping))
encoded_class_labels <- integer()
for(i in 1:length(g)){
  encoded_class_labels <- c(encoded_class_labels,which(names(g_mapping)==g[i]))
  #print(paste0("class name = ",g[i]," class label = ", which(names(g_mapping)==g[i])))
}
stopifnot(assertthat::are_equal(length(encoded_class_labels),length(g)))
stopifnot(assertthat::are_equal(max(encoded_class_labels),nrow(g_mapping)))

rna_seq_expr.df <- rse_gene %>% SummarizedExperiment::assay() %>% as.data.frame()
stopifnot(assertthat::are_equal(nrow(rna_seq_expr.df),58037))
stopifnot(assertthat::are_equal(ncol(rna_seq_expr.df),length(encoded_class_labels)))

print(paste("reducing expression matrix from",nrow(rna_seq_expr.df),"to",NUM_FEATURES,"random features",sep=" "))

random_selection <- sample(nrow(rna_seq_expr.df),NUM_FEATURES) #Only uniform sampling is supported.
random_selection_from_rna_seq_expr.df <- rna_seq_expr.df[random_selection,]
stopifnot(assertthat::are_equal(nrow(random_selection_from_rna_seq_expr.df),NUM_FEATURES))

transposed.df <- random_selection_from_rna_seq_expr.df %>% t() %>% as.data.frame()
transposed.df$sample_type <- encoded_class_labels
stopifnot(assertthat::are_equal(nrow(transposed.df),length(encoded_class_labels)))
stopifnot(assertthat::are_equal(ncol(transposed.df),nrow(random_selection_from_rna_seq_expr.df)+1))

transposed.df %>% lapply(.,sum) %>% unlist()
transposed.df %>% lapply(.,mean) %>% unlist()

saveRDS(transposed.df,file = paste(DATA_DIR,OUTPUT_DATA_FN,sep=""))
print(paste(OUTPUT_DATA_FN,"saved to",DATA_DIR,sep=" "))
# Out:
# .
#        Breast           CRC           GBM            HC Hepatobiliary
#            38            41            40            60            14
#          Lung      Pancreas
#            60            35
# [1] "Breast"        "CRC"           "GBM"           "HC"
# [5] "Hepatobiliary" "Lung"          "Pancreas"
# [1] "reducing expression matrix from 58037 to 16 random features"
#  ENSG00000283590.1 ENSG00000129221.15  ENSG00000231986.1  ENSG00000227556.1
#             196074             160984               4931                438
#  ENSG00000182898.3  ENSG00000274510.1  ENSG00000173404.4 ENSG00000170035.15
#              41885              16623              11912           36427244
#  ENSG00000248610.1  ENSG00000256513.1  ENSG00000231678.2  ENSG00000199585.1
#              14176              29566               3995               3519
#  ENSG00000227923.1  ENSG00000253861.1  ENSG00000205497.3  ENSG00000237074.2
#               3360             232789              14809              15683
#        sample_type
#               1155
#  ENSG00000283590.1 ENSG00000129221.15  ENSG00000231986.1  ENSG00000227556.1
#       6.808125e+02       5.589722e+02       1.712153e+01       1.520833e+00
#  ENSG00000182898.3  ENSG00000274510.1  ENSG00000173404.4 ENSG00000170035.15
#       1.454340e+02       5.771875e+01       4.136111e+01       1.264835e+05
#  ENSG00000248610.1  ENSG00000256513.1  ENSG00000231678.2  ENSG00000199585.1
#       4.922222e+01       1.026597e+02       1.387153e+01       1.221875e+01
#  ENSG00000227923.1  ENSG00000253861.1  ENSG00000205497.3  ENSG00000237074.2
#       1.166667e+01       8.082951e+02       5.142014e+01       5.445486e+01
#        sample_type
#       4.010417e+00
# [1] "transposed.Rds saved to ./"

# %%
dim(transposed.df)
# Out:
# [1] 288  17

# %%
head(transposed.df)
# Out:
#            ENSG00000283590.1 ENSG00000129221.15 ENSG00000231986.1
# SRR1982614   0               606                0
# SRR1982613 240               404                0
# SRR1982612 497                29                0
# SRR1982611 276                30                0
# SRR1982610   0                32                0
# SRR1982609   0                 0                0
#            ENSG00000227556.1 ENSG00000182898.3 ENSG00000274510.1
# SRR1982614 0                 387               101
# SRR1982613 0                   0                 0
# SRR1982612 0                   0               100
# SRR1982611 0                   0                 0
# SRR1982610 0                   0                 0
# SRR1982609 0                   0                 0
#            ENSG00000173404.4 ENSG00000170035.15 ENSG00000248610.1
# SRR1982614 0                  64814             0
# SRR1982613 0                  76125             0
# SRR1982612 0                  49822             0
# SRR1982611 0                 122014             0
# SRR1982610 0                  92583             0
# SRR1982609 0                  81050             0
#            ENSG00000256513.1 ENSG00000231678.2 ENSG00000199585.1
# SRR1982614  0                0                 0
# SRR1982613 76                0                 0
# SRR1982612  0                0                 0
# SRR1982611  0                0                 0
# SRR1982610  0                0                 0
# SRR1982609  0                0                 0
#            ENSG00000227923.1 ENSG00000253861.1 ENSG00000205497.3
# SRR1982614 0                    0              487
# SRR1982613 0                 1196                0
# SRR1982612 0                    0                0
# SRR1982611 0                    0                0
# SRR1982610 0                 2426                0
# SRR1982609 0                 2162                0
#            ENSG00000237074.2 sample_type
# SRR1982614 660               5
# SRR1982613   0               5
# SRR1982612   0               5
# SRR1982611   0               5
# SRR1982610   0               5
# SRR1982609   0               5

# %%
x = seq(1,7)
y = rep(1,7)

plot(x = x,
     y = y,
     col=x,
     pch=x,
     xlim = c(0.5,7.5),
     main="Class Symbols & Colors")

text(x,
     y + .07,
     srt = 45,
     labels=c("Breast","Colorectal","Brain","Healthy","Liver","Lung","Pancreas"))
# Out:
# Plot with title “Class Symbols & Colors”

# %%
set.seed(88888888)

library(scales)

DATA_DIR <- "./" #"/home/jgburk/PycharmProjects/IntroductionToDeepLearning/"
OUTPUT_DATA_FN <- "transposed.Rds"

NUM_TRAIN_IT <<- 500
ETA <<- 0.01 #step 2
RAND_POINTS <<- 500 # displays decision boundary
MCE_THRESH <<- 0.05 # maximum classwise error
RNA_SEQ_ANALYSIS <<- 1

# input layer
NUM_FEATURES <<- FEATURE_COUNT
INPUT_WIDTH <<- NUM_FEATURES + 1 # (bias)

# hidden layers
HIDDEN_LAYER_DEPTH <<- 3 #step 1
HIDDEN_CORE_DEPTH <<- HIDDEN_LAYER_DEPTH - 1 # special dims for final hidden layer
HIDDEN_LAYER_WIDTH <<- 8 # step 0
ANN_WIDTH <<- HIDDEN_LAYER_WIDTH + 1 # (bias)

# output layer
NUM_CLASSES <<- 7
OUTPUT_WIDTH <<- NUM_CLASSES

MAX_INIT <- .5
MIN_INIT <- -.5

# input layer
input_activation <<- matrix(data = 1,
                            nrow = INPUT_WIDTH, #includes bias
                            ncol = 1)
input_axon_w <<- matrix(data = runif(n = HIDDEN_LAYER_WIDTH * INPUT_WIDTH, min = MIN_INIT, max = MAX_INIT),
                        nrow = INPUT_WIDTH,
                        ncol = HIDDEN_LAYER_WIDTH)
# hidden core layers
hidden_core_deltas <<- matrix(data = 1,
                              nrow = ANN_WIDTH,
                              ncol = HIDDEN_CORE_DEPTH)
hidden_core_activation <<- matrix(data = 1,
                                  nrow = HIDDEN_LAYER_WIDTH,
                                  ncol = HIDDEN_CORE_DEPTH)
hidden_core_axon_w <<- array(data = runif(n =  HIDDEN_LAYER_WIDTH * ANN_WIDTH * HIDDEN_CORE_DEPTH, min = MIN_INIT, max = MAX_INIT),
                             dim = c(HIDDEN_LAYER_WIDTH,
                                     ANN_WIDTH,
                                     HIDDEN_CORE_DEPTH))

# hidden final layer
hidden_final_deltas <<- matrix(data = 1,
                               nrow = ANN_WIDTH,
                               ncol = 1)
hidden_final_activation <<- matrix(data = 1,
                                   nrow = HIDDEN_LAYER_WIDTH,
                                   ncol = 1)
hidden_final_axon_w <<- matrix(data = runif(n = ANN_WIDTH * OUTPUT_WIDTH, min = MIN_INIT, max = MAX_INIT),
                               nrow = ANN_WIDTH,
                               ncol = OUTPUT_WIDTH)
# output layer
output_deltas <<- matrix(data = 1,
                         nrow = OUTPUT_WIDTH,
                         ncol = 1)
output_activation <<- matrix(data = 1,
                             nrow = OUTPUT_WIDTH,
                             ncol = 1)

activation_function <- function(x){
  1/(1 + exp(-(x)))
}

activation_function_derivative <- function(x){
  activation_function(x)*(1 - activation_function(x))
}

forward_prop <- function(training_sample_features){
  # input layer
  input_activation <<- c(training_sample_features,1) # input_activation 17

  if(HIDDEN_CORE_DEPTH > 0){
    hidden_core_activation[,1] <<- # hidden_core_activation 30 x 9
      activation_function(t(input_axon_w) %*% input_activation) # input_axon_w 17 x 30

    if(HIDDEN_CORE_DEPTH > 1){
      for(core_layer in 2:HIDDEN_CORE_DEPTH){
        hidden_core_activation[,core_layer] <<- # hidden_core_activation 30 x 9
          activation_function(hidden_core_axon_w[,,core_layer - 1] %*% # hidden_core_axon_w 30 x 31 x 9
                                c(hidden_core_activation[,core_layer - 1],1)) # hidden_core_activation 30 x 9
      }
    }

    hidden_final_activation <<- # hidden_final_activation 30 x 1
      activation_function(hidden_core_axon_w[,,HIDDEN_CORE_DEPTH] %*% # hidden_core_axon_w 30 x 31 x 9
                            c(hidden_core_activation[,HIDDEN_CORE_DEPTH],1)) # hidden_core_activation 30 x 9
  }else{
    hidden_final_activation <<- # hidden_final_activation 30 x 1
      activation_function(t(input_axon_w) %*% # input_axon_w 17 x 30
                            input_activation) # input_activation 17
  }

  output_activation <<- # output_activation 7 x 1
    activation_function(t(hidden_final_axon_w) %*% # hidden_final_axon_w 31 x 7
                          c(hidden_final_activation,1)) # hidden_final_activation 30 x 1
}

encode_class <- function(sample_class){ # one-hot encoding
  ann_class_encoding <- numeric(NUM_CLASSES)
  ann_class_encoding[sample_class] <- 1
  return(ann_class_encoding)
}

calc_err <- function(sample_class){
  ann_class_encoding <- encode_class(sample_class)
  return(output_activation - ann_class_encoding)
}

backward_prop <- function(sample_class){
  output_deltas <<- calc_err(sample_class) #output_deltas 7 x 1

  hidden_final_deltas <<-        # hidden_final_deltas 31 x 1
    hidden_final_axon_w %*%      # hidden_final_axon_w 31 x 7 (delTotal/delW)
    output_deltas *              # output_deltas 7 x 1 (delETotal/delOut)
    activation_function_derivative(c(hidden_final_activation[1:HIDDEN_LAYER_WIDTH],1)) # hidden_final_activation 30 x 1 (delOut/delInput)

  if(HIDDEN_CORE_DEPTH > 0){
    hidden_core_deltas[,HIDDEN_CORE_DEPTH] <<-        # hidden_core_deltas 31 x 9
      (t(hidden_core_axon_w[,,HIDDEN_CORE_DEPTH]) %*%     # hidden_core_axon_w 30 x 31 x 9
         hidden_final_deltas[1:HIDDEN_LAYER_WIDTH]) *                           # hidden_final_deltas 31 x 1
      activation_function_derivative(c(hidden_core_activation[1:HIDDEN_LAYER_WIDTH,HIDDEN_CORE_DEPTH],1)) # hidden_core_activation 30 x 9

    if(HIDDEN_CORE_DEPTH > 1){
      for(core_layer in (HIDDEN_CORE_DEPTH - 1):1){
        hidden_core_deltas[,core_layer] <<-           # hidden_core_deltas 31 x 9
          (t(hidden_core_axon_w[,,core_layer]) %*%        # hidden_core_axon_w 30 x 31 x 9
             hidden_core_deltas[1:HIDDEN_LAYER_WIDTH,core_layer + 1]) *       # hidden_core_deltas 31 x 9
          activation_function_derivative(c(hidden_core_activation[1:HIDDEN_LAYER_WIDTH,core_layer],1)) # hidden_core_activation 30 x 9
      }
    }

    input_axon_w_jacobian <- input_activation %*% # input_activation 17
      t(hidden_core_deltas[1:HIDDEN_LAYER_WIDTH,1]) # hidden_core_deltas 31 x 9

    input_axon_w <<- # input_axon_w 17 x 30
      input_axon_w - # input_axon_w 17 x 30
      ETA *
      input_axon_w_jacobian

    if(HIDDEN_CORE_DEPTH > 1){
      for(core_layer in 1:(HIDDEN_CORE_DEPTH - 1)){
        hidden_core_axon_w_jacobian <- hidden_core_activation[,core_layer] %*% # hidden_core_activation 30 x 9
          t(hidden_core_deltas[,core_layer + 1]) # hidden_core_deltas 31 x 9

        hidden_core_axon_w[,,core_layer] <<- # hidden_core_axon_w 30 x 31 x 9
          hidden_core_axon_w[,,core_layer] - # hidden_core_axon_w 30 x 31 x 9
          ETA *
          hidden_core_axon_w_jacobian
      }
    }

    hidden_core_axon_w_jacobian <- hidden_core_activation[,HIDDEN_CORE_DEPTH] %*% # hidden_core_activation 30 x 9
      t(hidden_final_deltas) # hidden_final_deltas 31 x 1

    hidden_core_axon_w[,,HIDDEN_CORE_DEPTH] <<-     # hidden_core_axon_w 30 x 31 x 9
      hidden_core_axon_w[,,HIDDEN_CORE_DEPTH] -     # hidden_core_axon_w 30 x 31 x 9
      ETA *
      hidden_core_axon_w_jacobian

  }else{
    input_axon_w_jacobian <- input_activation %*% # input_activation 17
      t(hidden_final_deltas[1:HIDDEN_LAYER_WIDTH]) # hidden_final_deltas 31 x 1

    input_axon_w <<- # input_axon_w 17 x 30
      input_axon_w - # input_axon_w 17 x 30
      ETA *
      input_axon_w_jacobian
  }

  hidden_final_axon_w_jacobian <- c(hidden_final_activation,1) %*% # hidden_final_activation 30 x 1
    t(output_deltas) # output_deltas 7 x 1

  hidden_final_axon_w <<- # hidden_final_axon_w 31 x 7
    hidden_final_axon_w - # hidden_final_axon_w 31 x 7
    ETA *
    hidden_final_axon_w_jacobian

  return(mean(abs(output_activation - encode_class(sample_class))))
}

GLOB_ERR_1 <<- c()
GLOB_ERR_2 <<- c()
GLOB_ERR_3 <<- c()
GLOB_ERR_4 <<- c()
GLOB_ERR_5 <<- c()
GLOB_ERR_6 <<- c()
GLOB_ERR_7 <<- c()
GLOB_MAX_CLASSWISE_ERR <<- c()

train <- function(training_samples_features, training_samples_classes){
  error_sum <- c()
  classwise_errors <- c()
  mean_error_sum <- c()
  for(x in 1:NUM_TRAIN_IT){
    error1 <- c()
    error2 <- c()
    error3 <- c()
    error4 <- c()
    error5 <- c()
    error6 <- c()
    error7 <- c()
    for(i in 1:nrow(training_samples_features)){
      #i <- ceiling(runif(n=1,min=0,max=nrow(training_samples_features)))
      forward_prop(training_samples_features[i,])
      error <- backward_prop(training_samples_classes[i])
      error_sum <- c(error_sum,error)
      classwise_errors <- c(classwise_errors,error)

      if(training_samples_classes[i] == 1){
        error1 <- c(error1,error)
      }else if(training_samples_classes[i] == 2){
        error2 <- c(error2,error)
      }else if(training_samples_classes[i] == 3){
        error3 <- c(error3,error)
      }else if(training_samples_classes[i] == 4){
        error4 <- c(error4,error)
      }else if(training_samples_classes[i] == 5){
        error5 <- c(error5,error)
      }else if(training_samples_classes[i] == 6){
        error6 <- c(error6,error)
      }else if(training_samples_classes[i] == 7){
        error7 <- c(error7,error)
      }
    }
    GLOB_ERR_1 <<- c(GLOB_ERR_1,mean(error1))
    GLOB_ERR_2 <<- c(GLOB_ERR_2,mean(error2))
    GLOB_ERR_3 <<- c(GLOB_ERR_3,mean(error3))
    GLOB_ERR_4 <<- c(GLOB_ERR_4,mean(error4))
    GLOB_ERR_5 <<- c(GLOB_ERR_5,mean(error5))
    GLOB_ERR_6 <<- c(GLOB_ERR_6,mean(error6))
    GLOB_ERR_7 <<- c(GLOB_ERR_7,mean(error7))

    mce <- max(classwise_errors) # maximum classwise error
    GLOB_MAX_CLASSWISE_ERR <<- c(GLOB_MAX_CLASSWISE_ERR,mce)
    print(paste("MCE ",x,": ",mce,sep=""))
    #zeta <- (mce / (2 * 3^(1/2)))
    mean_error_sum <- c(mean_error_sum,rep(mean(classwise_errors),nrow(training_samples_features)))
    #plot(error_sum, col = "black",main="Individual (Black) & Mean (Red) Errors")#,col=seq(1:nrow(training_samples_features)),pch = seq(1:nrow(training_samples_features)))
    #points(mean_error_sum, col="red")
    classwise_errors <- c() #clear classwise errors
    if (mce < MCE_THRESH){
      print(paste("mce < ",MCE_THRESH," achieved (mce = ",mce,"). Stopping...",sep=""))
      break
    }
  }
  plot(error_sum, col = "black",main="Individual (Black) & Mean (Red) Errors")#,col=seq(1:nrow(training_samples_features)),pch = seq(1:nrow(training_samples_features)))
  points(mean_error_sum, col="red")
}

predict1 <- function(test_sample_features){
  forward_prop(test_sample_features)
  prediction <- output_activation
  return(which(prediction == max(prediction)))
}

predict_n <- function(test_samples_features){
  ps <- c()
  for(i in 1:nrow(test_samples_features)){
    z <- predict1(test_samples_features[i,])
    if(length(z) > 2){
      print(z)
      z <- z[1]
    }
    ps <- c(ps,z)
  }
  print(length(ps))
  return(ps)
}

sample_data <- readRDS(paste(DATA_DIR,OUTPUT_DATA_FN,sep=""))
samples_f <- as.matrix(sample_data[,1:NUM_FEATURES])
samples_c <- as.matrix(sample_data[,NUM_FEATURES+1])
norm_samples_f <- matrix(nrow = nrow(samples_f),ncol = ncol(samples_f))
for(i in 1:ncol(samples_f)){
  norm_samples_f[,i] <- scales::rescale(samples_f[,i], to=c(0,1))
}

train(norm_samples_f, samples_c)
plot(norm_samples_f[,1:2],col=samples_c,pch=samples_c,main="True Labels")
pred_train <- predict_n(norm_samples_f)
plot(norm_samples_f[,1:2],col=pred_train,pch=pred_train,main="Predicted Labels")
rand_points <<- matrix(data = runif(n = NUM_FEATURES * RAND_POINTS),
                       nrow = RAND_POINTS,
                       ncol = NUM_FEATURES)
norm_rand_points <- scales::rescale(rand_points, to = c(0,1))
pred_classes <- predict_n(norm_rand_points)
plot(norm_rand_points[,1:2],col=pred_classes,pch=pred_classes,main="Decision Boundary")
training_misclass_rate <- sum(samples_c != pred_train) / length(pred_train)
print(paste("Train Misclass Rate: ",training_misclass_rate,sep=""))
plot(GLOB_ERR_1)
plot(GLOB_ERR_2)
plot(GLOB_ERR_3)
plot(GLOB_ERR_4)
plot(GLOB_ERR_5)
plot(GLOB_ERR_6)
plot(GLOB_ERR_7)
plot(GLOB_MAX_CLASSWISE_ERR)

hist(samples_c)

library(pROC)

mroc <- pROC::multiclass.roc(response=as.numeric(samples_c),predictor=as.numeric(pred_train))
for(roc in 1:length(mroc$rocs)){
  pROC::plot.roc(mroc$rocs[[roc]],main=paste("AUC = ",
                                             round(auc(mroc$rocs[[roc]]),digits=3),
                                             " for Targets ",
                                             mroc$rocs[[roc]]$levels[1],
                                             " and ",
                                             mroc$rocs[[roc]]$levels[2],
                                             sep=""))
}
# Out:
# [1] "MCE 1: 0.6022843173562"
# [1] "MCE 2: 0.323034515663478"
# [1] "MCE 3: 0.280614171402554"
# [1] "MCE 4: 0.275647607708893"
# [1] "MCE 5: 0.274810998961529"
# [1] "MCE 6: 0.274817495474279"
# [1] "MCE 7: 0.274950147640335"
# [1] "MCE 8: 0.275062342962498"
# [1] "MCE 9: 0.275136037973062"
# [1] "MCE 10: 0.275178805320844"
# [1] "MCE 11: 0.275200377402849"
# [1] "MCE 12: 0.275208197846837"
# [1] "MCE 13: 0.275207296757092"
# [1] "MCE 14: 0.275200924961838"
# [1] "MCE 15: 0.275191145698973"
# [1] "MCE 16: 0.275179258669859"
# [1] "MCE 17: 0.275166080211184"
# [1] "MCE 18: 0.275152122623269"
# [1] "MCE 19: 0.275137707437474"
# [1] "MCE 20: 0.275123036564954"
# [1] "MCE 21: 0.275108236897235"
# [1] "MCE 22: 0.275093388251697"
# [1] "MCE 23: 0.275078540886032"
# [1] "MCE 24: 0.275063726481683"
# [1] "MCE 25: 0.27504896503672"
# [1] "MCE 26: 0.275034269195046"
# [1] "MCE 27: 0.275019646967665"
# [1] "MCE 28: 0.27500510344464"
# [1] "MCE 29: 0.274990641872977"
# [1] "MCE 30: 0.274976264335829"
# [1] "MCE 31: 0.274961972180845"
# [1] "MCE 32: 0.274947766290523"
# [1] "MCE 33: 0.274933647252983"
# [1] "MCE 34: 0.274919615469934"
# [1] "MCE 35: 0.274905671224982"
# [1] "MCE 36: 0.274891814726885"
# [1] "MCE 37: 0.274878046136969"
# [1] "MCE 38: 0.274864365586523"
# [1] "MCE 39: 0.274850773187833"
# [1] "MCE 40: 0.274837269041208"
# [1] "MCE 41: 0.274823853239442"
# [1] "MCE 42: 0.274810525870662"
# [1] "MCE 43: 0.274797287020144"
# [1] "MCE 44: 0.274784136771477"
# [1] "MCE 45: 0.274771075207309"
# [1] "MCE 46: 0.274758102409823"
# [1] "MCE 47: 0.274745218461058"
# [1] "MCE 48: 0.274732423443106"
# [1] "MCE 49: 0.274719717438248"
# [1] "MCE 50: 0.274707100529051"
# [1] "MCE 51: 0.274694572798424"
# [1] "MCE 52: 0.274682134329669"
# [1] "MCE 53: 0.274669785206512"
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
# Plot with title “Histogram of samples_c”
# Plot with title “AUC = 0.493 for Targets 1 and 2”
# Plot with title “AUC = 0.357 for Targets 1 and 3”
# Plot with title “AUC = 0.771 for Targets 1 and 4”
# Plot with title “AUC = 0.361 for Targets 1 and 5”
# Plot with title “AUC = 0.493 for Targets 1 and 6”
# Plot with title “AUC = 0.477 for Targets 1 and 7”
# Plot with title “AUC = 0.366 for Targets 2 and 3”
# Plot with title “AUC = 0.757 for Targets 2 and 4”
# Plot with title “AUC = 0.368 for Targets 2 and 5”
# Plot with title “AUC = 0.5 for Targets 2 and 6”
# Plot with title “AUC = 0.484 for Targets 2 and 7”
# Plot with title “AUC = 0.603 for Targets 3 and 4”
# Plot with title “AUC = 0.488 for Targets 3 and 5”
# Plot with title “AUC = 0.629 for Targets 3 and 6”
# Plot with title “AUC = 0.616 for Targets 3 and 7”
# Plot with title “AUC = 0.58 for Targets 4 and 5”
# Plot with title “AUC = 0.749 for Targets 4 and 6”
# Plot with title “AUC = 0.738 for Targets 4 and 7”
# Plot with title “AUC = 0.627 for Targets 5 and 6”
# Plot with title “AUC = 0.614 for Targets 5 and 7”
# Plot with title “AUC = 0.485 for Targets 6 and 7”

# %%
pdfCluster::adj.rand.index(pred_train, samples_c)
# Out:
# [1] 0.07068898

# %%
gc()
# Out:
#        used     (Mb)  gc trigger (Mb)  max used (Mb)
# Ncells  6575008 351.2 11968950   639.3 11968950 639.3
# Vcells 46111187 351.9 76851531   586.4 76851531 586.4

# %%
set.seed(88888888)

library(magrittr)
library(scales)
library(nnet)

DATA_DIR <- "./" #"/home/jgburk/PycharmProjects/IntroductionToDeepLearning/"
OUTPUT_DATA_FN <- "transposed.Rds"
NUM_FEATURES <<- FEATURE_COUNT
RAND_POINTS <<- 500 # displays decision boundary

sample_data <- readRDS(paste(DATA_DIR,OUTPUT_DATA_FN,sep=""))

samples_f <- as.matrix(sample_data[,1:NUM_FEATURES])
samples_c <- as.matrix(sample_data[,NUM_FEATURES+1])
norm_samples_f <- matrix(nrow = nrow(samples_f),ncol = ncol(samples_f))
for(i in 1:ncol(samples_f)){
  norm_samples_f[,i] <- scales::rescale(samples_f[,i], to=c(0,1))
}

nn_df <- data.frame(norm_samples_f)
nn_df$y <- as.factor(samples_c)

nn_model <- nnet::nnet(formula = y~.,
                       data=nn_df,
                       size=8,
                       maxitr=500)

nn_train_pred <- predict(object=nn_model,newdata=nn_df[,1:NUM_FEATURES])
pred_vec <- c()
for(i in 1:nrow(nn_train_pred)){
  pred_vec <- c(pred_vec,which(nn_train_pred[i,] == max(nn_train_pred[i,])))
}
plot(nn_df[,1:2],col=pred_vec,pch=pred_vec,main="nnet Predicted Labels")
nn_training_misclass_rate <- sum(as.numeric(nn_df$y) != pred_vec) / length(pred_vec)
print(paste("nnet Train Misclass Rate: ",nn_training_misclass_rate,sep=""))
rand_points <<- matrix(data = runif(n = NUM_FEATURES * RAND_POINTS),
                       nrow = RAND_POINTS,
                       ncol = NUM_FEATURES)
norm_rand_points <- scales::rescale(rand_points, to = c(0,1))
norm_rand_points_df <- data.frame(norm_rand_points)
colnames(norm_rand_points_df) <- colnames(nn_df[,1:NUM_FEATURES])
nn_pred_classes <- predict(object=nn_model,newdata=norm_rand_points_df)
pred_vec2 <- c()
for(i in 1:nrow(nn_pred_classes)){
  pred_vec2 <- c(pred_vec2,which(nn_pred_classes[i,] == max(nn_pred_classes[i,])))
}
plot(norm_rand_points[,1:2],col=pred_vec2,pch=pred_vec2,main="nnet Decision Boundary")

library(pROC)
mroc <- pROC::multiclass.roc(response=as.numeric(nn_df$y),predictor=as.numeric(pred_vec))
for(roc in 1:length(mroc$rocs)){
 pROC::plot.roc(mroc$rocs[[roc]],main=paste("nnet AUC = ",
                                            round(auc(mroc$rocs[[roc]]),digits=3),
                                            " for Targets ",
                                            mroc$rocs[[roc]]$levels[1],
                                            " and ",
                                            mroc$rocs[[roc]]$levels[2],
                                            sep=""))
}
# Out:
# # weights:  199
# initial  value 610.901686
# iter  10 value 465.273229
# iter  20 value 428.603391
# iter  30 value 395.166407
# iter  40 value 368.259874
# iter  50 value 348.857486
# iter  60 value 331.851668
# iter  70 value 319.121951
# iter  80 value 308.030516
# iter  90 value 297.205837
# iter 100 value 288.983425
# final  value 288.983425
# stopped after 100 iterations
# [1] "nnet Train Misclass Rate: 0.388888888888889"
# Plot with title “nnet Predicted Labels”
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls > cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls < cases
#
# Setting direction: controls > cases
#
# Setting direction: controls > cases
# Plot with title “nnet Decision Boundary”
# Plot with title “nnet AUC = 0.637 for Targets 1 and 2”
# Plot with title “nnet AUC = 0.751 for Targets 1 and 3”
# Plot with title “nnet AUC = 0.782 for Targets 1 and 4”
# Plot with title “nnet AUC = 0.667 for Targets 1 and 5”
# Plot with title “nnet AUC = 0.761 for Targets 1 and 6”
# Plot with title “nnet AUC = 0.653 for Targets 1 and 7”
# Plot with title “nnet AUC = 0.732 for Targets 2 and 3”
# Plot with title “nnet AUC = 0.849 for Targets 2 and 4”
# Plot with title “nnet AUC = 0.618 for Targets 2 and 5”
# Plot with title “nnet AUC = 0.765 for Targets 2 and 6”
# Plot with title “nnet AUC = 0.572 for Targets 2 and 7”
# Plot with title “nnet AUC = 0.788 for Targets 3 and 4”
# Plot with title “nnet AUC = 0.495 for Targets 3 and 5”
# Plot with title “nnet AUC = 0.708 for Targets 3 and 6”
# Plot with title “nnet AUC = 0.575 for Targets 3 and 7”
# Plot with title “nnet AUC = 0.563 for Targets 4 and 5”
# Plot with title “nnet AUC = 0.753 for Targets 4 and 6”
# Plot with title “nnet AUC = 0.68 for Targets 4 and 7”
# Plot with title “nnet AUC = 0.71 for Targets 5 and 6”
# Plot with title “nnet AUC = 0.529 for Targets 5 and 7”
# Plot with title “nnet AUC = 0.645 for Targets 6 and 7”

# %%
pdfCluster::adj.rand.index(pred_vec, samples_c)
# Out:
# [1] 0.391346

# %%
install.packages("NeuralNetTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘reshape2’

# %%
NeuralNetTools::plotnet(nn_model)
# Out:
# plot without title

# %%
# for the next section
t2_df <- readRDS("./transposed2.Rds")
dim(t2_df)
head(t2_df)
# Out:
# [1]  288 1001
#            ENSG00000283590.1 ENSG00000129221.15 ENSG00000231986.1
# SRR1982614   0               606                0
# SRR1982613 240               404                0
# SRR1982612 497                29                0
# SRR1982611 276                30                0
# SRR1982610   0                32                0
# SRR1982609   0                 0                0
#            ENSG00000227556.1 ENSG00000182898.3 ENSG00000274510.1
# SRR1982614 0                 387               101
# SRR1982613 0                   0                 0
# SRR1982612 0                   0               100
# SRR1982611 0                   0                 0
# SRR1982610 0                   0                 0
# SRR1982609 0                   0                 0
#            ENSG00000173404.4 ENSG00000170035.15 ENSG00000248610.1
# SRR1982614 0                  64814             0
# SRR1982613 0                  76125             0
# SRR1982612 0                  49822             0
# SRR1982611 0                 122014             0
# SRR1982610 0                  92583             0
# SRR1982609 0                  81050             0
#            ENSG00000256513.1 ⋯ ENSG00000265428.1 ENSG00000240589.3
# SRR1982614  0                ⋯ 0                   0
# SRR1982613 76                ⋯ 0                 181
# SRR1982612  0                ⋯ 0                   0
# SRR1982611  0                ⋯ 0                   0
# SRR1982610  0                ⋯ 0                   0
# SRR1982609  0                ⋯ 0                   0
#            ENSG00000261773.1 ENSG00000280135.1 ENSG00000142675.17
# SRR1982614 0                 909               152
# SRR1982613 0                  78                 0
# SRR1982612 0                   0                 0
# SRR1982611 0                   0                 0
# SRR1982610 0                 100                 0
# SRR1982609 0                   0                 0
#            ENSG00000279439.1 ENSG00000241735.1 ENSG00000280123.1
# SRR1982614    0              1183               102
# SRR1982613 1512               176               303
# SRR1982612    0                 0                 0
# SRR1982611    0              1883              2435
# SRR1982610    0                 0                 0
# SRR1982609   24              1001                 0
#            ENSG00000148634.15 sample_type
# SRR1982614  4361              5
# SRR1982613 15242              5
# SRR1982612  4981              5
# SRR1982611  9088              5
# SRR1982610 15225              5
# SRR1982609  3387              5
